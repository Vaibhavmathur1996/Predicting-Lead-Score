# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import pyplot as plt
from sklearn.cross_validation import KFold
from sklearn import datasets
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from pandas import Series, DataFrame
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn import tree
from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge

# %%
df = pd.read_csv("/home/vaibhavmathur/Desktop/Capitalvia/Lead Score Prediction/leads-and-customers.csv")
df.head()
Y=df['score']
df.drop(['score'], axis=1, inplace=True)

# %%
title1=list()
for info in df['mail']:
    a,b=info.split("@")
    title1.append(b)

# %%
title1
# Out:
# ['hotmail.com',
#  'yahoo.com',
#  'yahoo.com',
#  'gmail.com',
#  'gmail.com',
#  'gmail.com',
#  'gmail.com',
#  'hotmail.com',
#  'yahoo.com',
#  'hotmail.com',
#  'hotmail.com',
#  'hotmail.com',
#  'gmail.com',
#  'gmail.com',
#  'yahoo.com',
#  'gmail.com',
#  'gmail.com',
#  'yahoo.com',
#  'gmail.com',
#  'hotmail.com',
#  'yahoo.com',
#  'hotmail.com',
#  'hotmail.com',
#  'hotmail.com',
#  'hotmail.com',
#  'hotmail.com',
#  'gmail.com',
#  'hotmail.com',
#  'gmail.com',
#  'hotmail.com',
#  'hotmail.com',
#  'hotmail.com',
#  'hotmail.com',
#  'yahoo.com',
#  'yahoo.com',
#  'gmail.com',
#  'hotmail.com',
#  'hotmail.com',
#  'yahoo.com',
#  'hotmail.com',
#  'hotmail.com',
#  'gmail.com',
#  'yahoo.com',
#  'gmail.com',
#  'gmail.com',
#  'yahoo.com',
#  'yahoo.com',
#  'yahoo.com',
#  'hotmail.com',
#  'gmail.com',
#  'hotmail.com',
#  'hotmail.com',
#  'yahoo.com',
#  'hotmail.com',
#  'yahoo.com',
#  'gmail.com',
#  'hotmail.com',
#  'hotmail.com',
#  'yahoo.com',
# ...

# %%
df.columns
# Out:
# Index(['days_since_signup', 'completed_form', 'visited_pricing',
#        'registered_for_webinar', 'attended_webinar', 'converted', 'is_manager',
#        'acquisition_channel=_Cold Call', 'acquisition_channel=_Cold Email',
#        'acquisition_channel=_Organic Search',
#        'acquisition_channel=_Paid Leads', 'acquisition_channel=_Paid Search',
#        'company_size=_1-10', 'company_size=_1000-10000',
#        'company_size=_10001+', 'company_size=_101-250', 'company_size=_11-50',
#        'company_size=_251-1000', 'company_size=_51-100',
#        'industry=_Financial Services', 'industry=_Furniture',
#        'industry=_Heavy Manufacturing', 'industry=_Scandanavion Design',
#        'industry=_Transportation', 'industry=_Web & Internet', 'Year', 'Age',
#        'sex_F', 'sex_M', 'job_title_Director', 'job_title_Manager',
#        'job_title_Others', 'email_gmail.com', 'email_hotmail.com',
#        'email_yahoo.com'],
#       dtype='object')

# %%
df['email']=title1
df.head()
# Out:
#                                              address   birthdate  \
# 0  27105 Christopher Station\nKevinborough, WA 91...  2010-08-08
# 1      78597 Gina Grove\nNorth Rebeccaberg, IL 61475  1981-12-04
# 2          0628 Sanders Plains\nLake Jenna, VA 56410  1979-04-25
# 3  9774 Moore Square Suite 477\nGonzalezfurt, OR ...  2005-07-13
# 4  77324 John Tunnel\nSouth Shirleyfort, WA 36499...  1973-06-19
#
#                      mail              name sex         username  \
# 0     qturner@hotmail.com    Samuel Simpson   M    debrapeterson
# 1       carramy@yahoo.com  Angelica Sanchez   F          mbrooks
# 2        sbrown@yahoo.com     Connie Taylor   F     aarongriffin
# 3        bdixon@gmail.com      Alexis Jones   F   jeffreymorales
# 4  harrisandrea@gmail.com       Lisa Wright   F  hamiltoncameron
#
#    days_since_signup acquisition_channel                    job_title  \
# 0                 18      Organic Search           Marketing Director
# ...

# %%
df['job_title']=df['job_title'].replace(['Marketing Director','VP Promotions',
       'Management Information Systems Director',
       'Data Operations Director',
       'Information Technology Systems Director', 'E-Commerce Director', 'Information Systems Director',
       'Sales Director','MIS Director', 'Information Technology Director',
       'Application Development Director', 'Advertising Director',
       'Promotions Director'], 'Director')

# %%
df['job_title']=df['job_title']=df['job_title'].replace(['VP Marketing', 'VP Advertising',
       'Advertising Executive', 'Marketing Administrator',
       'Chief Technology Officer'],'Others')

# %%
df['job_title']=df['job_title'].replace(['Promotion Manager',
       'Information Systems Manager', 'Territory Sales Manager',
       'Data Processing Manager', 'Computer Operations Manager',
       'Export Manager', 'Regional Sales Manager','District Sales Manager', 'Internet Marketing Manager',
        'Classified Advertising Manager', 'Computer Security Manager', 'Internet Technology Manager',
                     'Sales Account Manager',
       'Advertising Manager'   ], 'Manager')

# %%
df.describe()
# Out:
#        days_since_signup  completed_form  visited_pricing  \
# count      100000.000000   100000.000000    100000.000000
# mean           14.549550        0.800380         0.880250
# std             8.640902        0.399717         0.324671
# min             0.000000        0.000000         0.000000
# 25%             7.000000        1.000000         1.000000
# 50%            15.000000        1.000000         1.000000
# 75%            22.000000        1.000000         1.000000
# max            29.000000        1.000000         1.000000
#
#        registered_for_webinar  attended_webinar      converted  \
# count           100000.000000     100000.000000  100000.000000
# mean                 0.199750          0.100700       0.228260
# std                  0.399814          0.300933       0.419713
# min                  0.000000          0.000000       0.000000
# 25%                  0.000000          0.000000       0.000000
# ...

# %%
df.columns
# Out:
# Index(['address', 'birthdate', 'mail', 'name', 'sex', 'username',
#        'days_since_signup', 'acquisition_channel', 'job_title', 'company_size',
#        'completed_form', 'visited_pricing', 'registered_for_webinar',
#        'attended_webinar', 'industry', 'converted', 'is_manager',
#        'acquisition_channel=_Cold Call', 'acquisition_channel=_Cold Email',
#        'acquisition_channel=_Organic Search',
#        'acquisition_channel=_Paid Leads', 'acquisition_channel=_Paid Search',
#        'company_size=_1-10', 'company_size=_1000-10000',
#        'company_size=_10001+', 'company_size=_101-250', 'company_size=_11-50',
#        'company_size=_251-1000', 'company_size=_51-100',
#        'industry=_Financial Services', 'industry=_Furniture',
#        'industry=_Heavy Manufacturing', 'industry=_Scandanavion Design',
#        'industry=_Transportation', 'industry=_Web & Internet', 'email'],
#       dtype='object')

# %%
df.describe()
df.drop(['address','mail', 'username', 'name', 'company_size' ,'acquisition_channel' ,'industry'], axis=1, inplace=True)

# %%
title2=list()
for info in df['birthdate']:
    year, month, date=info.split("-")
    title2.append(year)

df['Year']=pd.DataFrame(title2)

# %%
df['Year']
# Out:
# 0        2010
# 1        1981
# 2        1979
# 3        2005
# 4        1973
# 5        1980
# 6        1971
# 7        1983
# 8        1981
# 9        1981
# 10       2006
# 11       1986
# 12       1980
# 13       1984
# 14       1995
# 15       2015
# 16       1971
# 17       1984
# 18       2007
# 19       2009
# 20       1974
# 21       1987
# 22       2005
# 23       2002
# 24       1994
# 25       1977
# 26       2015
# 27       1979
# 28       1974
# 29       2000
#          ...
# 99970    1970
# 99971    2015
# 99972    1984
# 99973    1977
# 99974    1981
# 99975    2012
# 99976    2010
# 99977    1975
# 99978    2000
# 99979    1989
# 99980    2013
# 99981    1976
# 99982    1991
# 99983    2005
# 99984    1989
# 99985    2008
# 99986    2015
# 99987    1992
# 99988    2013
# 99989    1978
# 99990    2011
# 99991    1987
# 99992    1997
# 99993    1977
# 99994    1993
# 99995    1977
# 99996    1996
# 99997    1992
# 99998    1988
# 99999    2010
# ...

# %%
#df['Year']=int(df['Year'])
df.Year= df.Year.astype(int)

# %%
df['Age']=2018-df['Year']

# %%
df['Age']
# Out:
# 0         8
# 1        37
# 2        39
# 3        13
# 4        45
# 5        38
# 6        47
# 7        35
# 8        37
# 9        37
# 10       12
# 11       32
# 12       38
# 13       34
# 14       23
# 15        3
# 16       47
# 17       34
# 18       11
# 19        9
# 20       44
# 21       31
# 22       13
# 23       16
# 24       24
# 25       41
# 26        3
# 27       39
# 28       44
# 29       18
#          ..
# 99970    48
# 99971     3
# 99972    34
# 99973    41
# 99974    37
# 99975     6
# 99976     8
# 99977    43
# 99978    18
# 99979    29
# 99980     5
# 99981    42
# 99982    27
# 99983    13
# 99984    29
# 99985    10
# 99986     3
# 99987    26
# 99988     5
# 99989    40
# 99990     7
# 99991    31
# 99992    21
# 99993    41
# 99994    25
# 99995    41
# 99996    22
# 99997    26
# 99998    30
# 99999     8
# Name: Age, Length: 100000, dtype: int64

# %%
df.head(10)
df.shape
# Out:
# (100000, 31)

# %%
data=df.drop(['birthdate'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   sex  days_since_signup job_title  completed_form  visited_pricing  \
# 0   M                 18  Director               1                1
# 1   F                  3   Manager               1                0
# 2   F                 26   Manager               0                1
# 3   F                 19   Manager               1                1
# 4   F                  7   Manager               1                1
#
#    registered_for_webinar  attended_webinar  converted  is_manager  \
# 0                       0                 0          1        True
# 1                       1                 0          0       False
# 2                       0                 0          0       False
# 3                       1                 1          1       False
# 4                       0                 0          0       False
#
#    acquisition_channel=_Cold Call ...   company_size=_51-100  \
# 0                               0 ...                      0
# ...

# %%
#y=df['score']
#df.drop(['score'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['sex', 'days_since_signup', 'job_title', 'completed_form',
#        'visited_pricing', 'registered_for_webinar', 'attended_webinar',
#        'converted', 'is_manager', 'acquisition_channel=_Cold Call',
#        'acquisition_channel=_Cold Email',
#        'acquisition_channel=_Organic Search',
#        'acquisition_channel=_Paid Leads', 'acquisition_channel=_Paid Search',
#        'company_size=_1-10', 'company_size=_1000-10000',
#        'company_size=_10001+', 'company_size=_101-250', 'company_size=_11-50',
#        'company_size=_251-1000', 'company_size=_51-100',
#        'industry=_Financial Services', 'industry=_Furniture',
#        'industry=_Heavy Manufacturing', 'industry=_Scandanavion Design',
#        'industry=_Transportation', 'industry=_Web & Internet', 'email', 'Year',
#        'Age'],
#       dtype='object')

# %%
mylist = list(df.select_dtypes(include=['object']).columns)

mylist
dummies = pd.get_dummies(df[mylist], prefix= mylist)
df.drop(mylist, axis=1, inplace=True)
df=pd.concat([df,dummies], axis=1)
mylist
# Out:
# ['sex', 'job_title', 'email']

# %%
X_train, X_cv, Y_train, Y_cv=train_test_split(df, Y,train_size=0.8, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor
model= RandomForestRegressor(n_estimators=1000, max_depth=7)

# %%
model.fit(X_train, Y_train)
pred_cv=model.predict(X_cv)

# %%
mse=np.mean((pred_cv-Y_cv)**2)

# %%
mse
# Out:
# 1226.032388367563

# %%
model.score(X_cv, Y_cv)
# Out:
# 0.6785480898621379

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
#Gives the best MSE-1058.2357 with 100, 0.1, 7
clf=GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=7)
clf.fit(X_train,Y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=7, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
predict1=clf.predict(X_cv)

# %%
mse1=np.mean((predict1-Y_cv)**2)

# %%
mse1
# Out:
# 1146.5182399876314

# %%
clf.score(X_cv, Y_cv)
# Out:
# 0.6993958057318155

# %%
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=5, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
#from sklearn.model_selection import KFold
#from sklearn.model_selection import RepeatedKFold

#kf = RepeatedKFold(n_splits=5, n_repeats=10, random_state=None)

# %%
#for train_index, test_index in kf.split(X_train):
#         print("Train:", train_index, "Validation:",test_index)
#X_tr, X_te = X_train[train_index], X_train[test_index] 
#

# %%
#df = pd.read_csv("/home/vincy/Desktop/demo-lead-scoring-master/data/leads-and-customers.csv")
#df
#df.shape

# %%
#seed=7

# %%
#df.drop(['score'], axis=1, inplace=True)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %%
X_train, X_cv, Y_train, Y_cv = train_test_split(df, Y,train_size=0.7, test_size=0.3)

# %%
model1=XGBClassifier()

# %%
model1.fit(X_train,Y_train)

# %%
print(model1)

# %%
pred_cv=model1.predict(X_cv)

# %%
mse=np.mean((pred_cv-Y_cv)**2)
mse

# %%
model1.score(X_cv, Y_cv)

# %%
accuracy = accuracy_score(Y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %%
from tpot import TPOTRegressor
from sklearn import preprocessing

# %%
tpot = TPOTRegressor(generations=10, population_size=50, verbosity=2)
tpot.fit(X_train, Y_train)
print(tpot.score(X_cv, Y_cv))
tpot.export('leaddata.py')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-f6deaa384329> in <module>()
#       1 tpot = TPOTRegressor(generations=10, population_size=50, verbosity=2)
# ----> 2 tpot.fit(X_train, Y_train)
#       3 print(tpot.score(X_cv, Y_cv))
#       4 tpot.export('leaddata.py')
#
# ~/anaconda3/lib/python3.6/site-packages/tpot/base.py in fit(self, features, target, sample_weight, groups)
#     540         """
#     541
# --> 542         features, target = self._check_dataset(features, target)
#     543
#     544         # Randomly collect a subsample of training samples for pipeline optimization process.
#
# ~/anaconda3/lib/python3.6/site-packages/tpot/base.py in _check_dataset(self, features, target)
#    1020                 )
#    1021         else:
# -> 1022             if np.any(np.isnan(features)):
#    1023                 self._imputed = True
# ...

# %%
X_train.describe()
# Out:
#        days_since_signup  completed_form  visited_pricing  \
# count       80000.000000    80000.000000     80000.000000
# mean           14.553600        0.800300         0.879337
# std             8.634387        0.399777         0.325737
# min             0.000000        0.000000         0.000000
# 25%             7.000000        1.000000         1.000000
# 50%            15.000000        1.000000         1.000000
# 75%            22.000000        1.000000         1.000000
# max            29.000000        1.000000         1.000000
#
#        registered_for_webinar  attended_webinar     converted  \
# count            80000.000000      80000.000000  80000.000000
# mean                 0.200013          0.100750      0.228213
# std                  0.400012          0.300999      0.419683
# min                  0.000000          0.000000      0.000000
# 25%                  0.000000          0.000000      0.000000
# 50%                  0.000000          0.000000      0.000000
# ...

# %%
#Gives the second MSE
modelt= tree.DecisionTreeClassifier(criterion='entropy')
modelt=tree.DecisionTreeRegressor(max_depth=12)
modelt.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=12, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
predictedt=modelt.predict(X_cv)

# %%
from math import sqrt
mset=np.mean((predictedt-Y_cv)**2)

# %%
mset
# Out:
# 1126.5992669194172

# %%
modelt.score(X_cv, Y_cv)
# Out:
# 0.7056060136162102
